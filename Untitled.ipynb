# %%
import h5py
filename = "maze2d-open-sparse.hdf5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['actions', 'infos', 'observations', 'rewards', 'terminals', 'timeouts']>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/nn/z5pzxnxs629_tnqpvr431_fm0000gn/T/ipykernel_11594/864965509.py in <module>
#       8
#       9     # Get the data
# ---> 10     data = list(f[a_group_key])
#
# ~/miniforge3/lib/python3.9/site-packages/h5py/_hl/dataset.py in __iter__(self)
#     659             raise TypeError("Can't iterate over a scalar dataset")
#     660         for i in range(shape[0]):
# --> 661             yield self[i]
#     662
#     663     @with_phil
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/miniforge3/lib/python3.9/site-packages/h5py/_hl/dataset.py in __getitem__(self, args, new_dtype)
#     785         mspace = h5s.create_simple(selection.mshape)
#     786         fspace = selection.id
# --> 787         self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     788
#     789         # Patch up the output for NumPy
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
f = h5py.File(filename, "r")

# %%
obs = np.array(f['observations'])
actions = np.array(f['actions'])

# %%
np.unique(actions).shape
# Out:
# (952544,)

# %%
actions[:,0]
# Out:
# array([-0.6828367 , -0.51389796, -0.37335745, ..., -0.03562365,
#        -0.03098808,  0.82023513], dtype=float32)

# %%
plt.hist(actions[:,1])
# Out:
# (array([382686.,  19157.,  21873.,  31095.,  58011.,  48977.,  18484.,
#          14393.,  14543., 390781.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ],
#        dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(obs[:,0])
# Out:
# (array([180703.,  86359.,  27157.,  29238., 180222., 228927.,  26171.,
#          23412.,  48379., 169432.]),
#  array([0.7430846 , 0.97657853, 1.2100724 , 1.4435663 , 1.6770602 ,
#         1.9105542 , 2.144048  , 2.377542  , 2.6110358 , 2.8445299 ,
#         3.0780237 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
actions.shape
# Out:
# (1000000, 2)
